# %% [markdown]
# # 1-misol

# %%
import numpy as np
massiv=np.full((4, 5), 9)
massiv2=np.random.randint(1, 33, (4, 5))
massiv3=np.arange(0,40,2)
massiv4=np.linspace(0,10,20)

# %%
massiv.shape
# Out:
# (4, 5)

# %%
massiv2.size
# Out:
# 20

# %%
massiv3.ndim
# Out:
# 1

# %%
massiv4.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # 2-misol

# %%
import pandas as pd

me = {
    "ism": ["Ahmadjon"],
    "familiya": ["Ahmadov"],
    "viloyat": ["Xorazm"],
    "tuman": ["Xonqa"],
    "yosh": [24]
}
df = pd.DataFrame(me)
print(df)
# Out:
#         ism familiya viloyat  tuman  yosh
# 0  Ahmadjon  Ahmadov  Xorazm  Xonqa    24

# %%
df = pd.read_csv(r"/home/ahmadjon/Desktop/ML-course/1-oy/3-dars/homework/Data/cars_2010_2020.csv")
df.describe()

# %% [markdown]
# Eng qimmat 5 mashina

# %%
df.groupby(['Make','Model'])['Price (USD)'].max().head()
# Out:
# Make  Model
# Audi  A3       79973.56
#       A4       78970.52
#       A6       79969.78
#       Q5       79882.42
#       Q7       79804.08
# Name: Price (USD), dtype: float64
